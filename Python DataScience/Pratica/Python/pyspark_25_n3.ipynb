# %%
#criar ambiente de sessão spark em memoria

#instalando bibiloteca pyspark
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession as ss
from pyspark.sql import functions as f
from pyspark.sql.types import DoubleType

# %%
#criando objeto spark
spark = ss.builder.appName("SENAI").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://61e7095dac60:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SENAI</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dados = (
    ("ana" ,  "analista" , 6200),
    ("joao" , "assistente", 3100),
    ("julio" , "analista", 7900),
    ("bruna" , "coordenadora", 16000),
    ("pedro" , "coordenador" , 15000),
    ("felipe" , "auxiliar" , 2500)
)

# %%
colunas = ("funcionarios" , "funcao" , "salario")

# %%
#criando data frame manual

df1 = spark.createDataFrame(dados,colunas)

# %%
df1.toPandas()
# Out:
#   funcionarios        funcao  salario
# 0          ana      analista     6200
# 1         joao    assistente     3100
# 2        julio      analista     7900
# 3        bruna  coordenadora    16000
# 4        pedro   coordenador    15000
# 5       felipe      auxiliar     2500

# %%
dados = (
    ("caludio","analista", 5800),
    ("beatriz","assistente",3300)
)

# %%
df2 = spark.createDataFrame(dados,colunas)

# %%
df2.show()
# Out:
# +------------+----------+-------+
# |funcionarios|    funcao|salario|
# +------------+----------+-------+
# |     caludio|  analista|   5800|
# |     beatriz|assistente|   3300|
# +------------+----------+-------+

# %%
df = df1.union(df2)

# %%
df.show()
# Out:
# +------------+------------+-------+
# |funcionarios|      funcao|salario|
# +------------+------------+-------+
# |         ana|    analista|   6200|
# |        joao|  assistente|   3100|
# |       julio|    analista|   7900|
# |       bruna|coordenadora|  16000|
# |       pedro| coordenador|  15000|
# |      felipe|    auxiliar|   2500|
# |     caludio|    analista|   5800|
# |     beatriz|  assistente|   3300|
# +------------+------------+-------+

# %%
df.toPandas()
# Out:
#   funcionarios        funcao  salario
# 0          ana      analista     6200
# 1         joao    assistente     3100
# 2        julio      analista     7900
# 3        bruna  coordenadora    16000
# 4        pedro   coordenador    15000
# 5       felipe      auxiliar     2500
# 6      caludio      analista     5800
# 7      beatriz    assistente     3300
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['salario'].plot(kind='hist', bins=20, title='salario')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('funcionarios').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('funcao').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['salario'].plot(kind='line', figsize=(8, 4), title='salario')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['funcao'].value_counts()
#     for x_label, grp in _df_4.groupby('funcionarios')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('funcionarios')
# _ = plt.ylabel('funcao')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_5['funcionarios'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_5, x='salario', y='funcionarios', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_6['funcao'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_6, x='salario', y='funcao', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
#exibir informaçeoes sobre tipos de dados e nomes de colunas do data frame
df.printSchema()
# Out:
# root
#  |-- funcionarios: string (nullable = true)
#  |-- funcao: string (nullable = true)
#  |-- salario: long (nullable = true)

# %%
# adicionando nova coluna no data frame spark:

df.withColumn("cenario1",
              f.round(df.salario * 1.05)).show()
# Out:
# +------------+------------+-------+--------+
# |funcionarios|      funcao|salario|cenario1|
# +------------+------------+-------+--------+
# |         ana|    analista|   6200|  6510.0|
# |        joao|  assistente|   3100|  3255.0|
# |       julio|    analista|   7900|  8295.0|
# |       bruna|coordenadora|  16000| 16800.0|
# |       pedro| coordenador|  15000| 15750.0|
# |      felipe|    auxiliar|   2500|  2625.0|
# |     caludio|    analista|   5800|  6090.0|
# |     beatriz|  assistente|   3300|  3465.0|
# +------------+------------+-------+--------+

# %%
#efetivando a alteração do df
df = df.withColumn("cenario1",
              f.round(df.salario * 1.05))

# %%
df.toPandas()
# Out:
#   funcionarios        funcao  salario  cenario1
# 0          ana      analista     6200    6510.0
# 1         joao    assistente     3100    3255.0
# 2        julio      analista     7900    8295.0
# 3        bruna  coordenadora    16000   16800.0
# 4        pedro   coordenador    15000   15750.0
# 5       felipe      auxiliar     2500    2625.0
# 6      caludio      analista     5800    6090.0
# 7      beatriz    assistente     3300    3465.0

# %%
#criando coluna condicional
#no novo cenario sera aplicado um reajuste para quem ganha
#ate 5000. para outro salario sera o reajuste padrão de 5%.

df.withColumn("cenario2",
              f.when(df.salario<= 5000, df.salario * 1.07).otherwise(df.salario * 1.05)).show()
# Out:
# +------------+------------+-------+--------+--------+
# |funcionarios|      funcao|salario|cenario1|cenario2|
# +------------+------------+-------+--------+--------+
# |         ana|    analista|   6200|  6510.0|  6510.0|
# |        joao|  assistente|   3100|  3255.0|  3317.0|
# |       julio|    analista|   7900|  8295.0|  8295.0|
# |       bruna|coordenadora|  16000| 16800.0| 16800.0|
# |       pedro| coordenador|  15000| 15750.0| 15750.0|
# |      felipe|    auxiliar|   2500|  2625.0|  2675.0|
# |     caludio|    analista|   5800|  6090.0|  6090.0|
# |     beatriz|  assistente|   3300|  3465.0|  3531.0|
# +------------+------------+-------+--------+--------+

# %%
df = df.withColumn("cenario2",
              f.when(df.salario<= 5000, df.salario * 1.07).otherwise(df.salario * 1.05))

# %%
df.toPandas()
# Out:
#   funcionarios        funcao  salario  cenario1  cenario2
# 0          ana      analista     6200    6510.0    6510.0
# 1         joao    assistente     3100    3255.0    3317.0
# 2        julio      analista     7900    8295.0    8295.0
# 3        bruna  coordenadora    16000   16800.0   16800.0
# 4        pedro   coordenador    15000   15750.0   15750.0
# 5       felipe      auxiliar     2500    2625.0    2675.0
# 6      caludio      analista     5800    6090.0    6090.0
# 7      beatriz    assistente     3300    3465.0    3531.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['salario'].plot(kind='hist', bins=20, title='salario')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['cenario1'].plot(kind='hist', bins=20, title='cenario1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['cenario2'].plot(kind='hist', bins=20, title='cenario2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_10.groupby('funcionarios').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_11.groupby('funcao').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12.plot(kind='scatter', x='salario', y='cenario1', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13.plot(kind='scatter', x='cenario1', y='cenario2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['salario'].plot(kind='line', figsize=(8, 4), title='salario')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['cenario1'].plot(kind='line', figsize=(8, 4), title='cenario1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['cenario2'].plot(kind='line', figsize=(8, 4), title='cenario2')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['funcao'].value_counts()
#     for x_label, grp in _df_17.groupby('funcionarios')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('funcionarios')
# _ = plt.ylabel('funcao')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['funcionarios'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='salario', y='funcionarios', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['funcao'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='salario', y='funcao', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['funcionarios'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='cenario1', y='funcionarios', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['funcao'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='cenario1', y='funcao', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
#filtrando dados:
df.where("salario >= 7000").show()
# Out:
# +------------+------------+-------+--------+--------+
# |funcionarios|      funcao|salario|cenario1|cenario2|
# +------------+------------+-------+--------+--------+
# |       julio|    analista|   7900|  8295.0|  8295.0|
# |       bruna|coordenadora|  16000| 16800.0| 16800.0|
# |       pedro| coordenador|  15000| 15750.0| 15750.0|
# +------------+------------+-------+--------+--------+

# %%
df.where("funcao like '%coord%'").show()
# Out:
# +------------+------------+-------+--------+--------+
# |funcionarios|      funcao|salario|cenario1|cenario2|
# +------------+------------+-------+--------+--------+
# |       bruna|coordenadora|  16000| 16800.0| 16800.0|
# |       pedro| coordenador|  15000| 15750.0| 15750.0|
# +------------+------------+-------+--------+--------+

# %%
#importando dataframe .csv
url= "/content/drive/MyDrive/BasesPark/empresas-20251002T220344Z-1-001/empresas/part*"
empresas = spark.read.csv(
    url,
    sep=";",
    header=True,
    inferSchema=True,
    encoding="latin1"
)

# %%
empresas.show()
# Out:
# +-----+--------------------+-----------------+------------------------+--------------+-----+---------------+
# | cnpj|        razao_social|natureza_juridica|qualificacao_responsavel|capital_social|porte|ente_federativo|
# +-----+--------------------+-----------------+------------------------+--------------+-----+---------------+
# |  306|FRANCAMAR REFRIGE...|             2240|                      49|          0,00|    1|           NULL|
# | 1355|BRASILEIRO & OLIV...|             2062|                      49|          0,00|    5|           NULL|
# | 4820|REGISTRO DE IMOVE...|             3034|                      32|          0,00|    5|           NULL|
# | 5347|ROSELY APARECIDA ...|             2135|                      50|          0,00|    5|           NULL|
# | 6846|BADU E FILHOS TEC...|             2062|                      49|       4000,00|    1|           NULL|
# | 8416|  ELETRICA RUBI LTDA|             2062|                      49|          0,00|    5|           NULL|
# | 8992|SHIROMA VEICULOS ...|             2062|                      49|          0,00|    5|           NULL|
# | 9091|CONTATOS BAR E LA...|             2062|                      49|          0,00|    5|           NULL|
# | 9614|ANTONIA APARECIDA...|             2135|                      50|          0,00|    5|           NULL|
# | 9896|DORACY CORAT DA C...|             2135|                      50|          0,00|    5|           NULL|
# |12112|LANCHONETE RIO VE...|             2062|                      49|          0,00|    5|           NULL|
# |12605|VALMAR JACAREI CO...|             2062|                      49|          0,00|    5|           NULL|
# |13407|ROSANA CRISTINA D...|             2135|                      50|          0,00|    5|           NULL|
# |13408|CELIO RODRIGUES D...|             2135|                      50|          0,00|    5|           NULL|
# |13721|MAQFRAN COMERCIO ...|             2062|                      49|          0,00|    1|           NULL|
# |21181|MOURA & SILVA MER...|             2062|                      49|          0,00|    5|           NULL|
# |21858|PAMARATI COMERCIO...|             2135|                      50|          0,00|    1|           NULL|
# |22277|INACIO RODRIGUES ...|             2135|                      50|          0,00|    5|           NULL|
# |24205|SUELY LEME MARI A...|             2135|                      50|       1000,00|    1|           NULL|
# |26805|SUELI BATISTA DA ...|             2135|                      50|          0,00|    5|           NULL|
# +-----+--------------------+-----------------+------------------------+--------------+-----+---------------+
# only showing top 20 rows

# %%
empresas.printSchema()
# Out:
# root
#  |-- cnpj: integer (nullable = true)
#  |-- razao_social: string (nullable = true)
#  |-- natureza_juridica: integer (nullable = true)
#  |-- qualificacao_responsavel: integer (nullable = true)
#  |-- capital_social: string (nullable = true)
#  |-- porte: integer (nullable = true)
#  |-- ente_federativo: string (nullable = true)

# %%
# uso do toPandas com muitas linhas
empresas.limit(20).toPandas()
# Out:
#      cnpj                                       razao_social  \
# 0     306            FRANCAMAR REFRIGERACAO TECNICA S/C LTDA
# 1    1355                         BRASILEIRO & OLIVEIRA LTDA
# 2    4820  REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E ...
# 3    5347       ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS
# 4    6846                         BADU E FILHOS TECIDOS LTDA
# 5    8416                                 ELETRICA RUBI LTDA
# 6    8992                             SHIROMA VEICULOS LTDA.
# 7    9091                     CONTATOS BAR E LANCHONETE LTDA
# 8    9614                  ANTONIA APARECIDA DE SOUZA ULIANA
# 9    9896                              DORACY CORAT DA COSTA
# 10  12112                       LANCHONETE RIO VERMELHO LTDA
# 11  12605  VALMAR JACAREI COMERCIO DE PRODUTOS ALIMENTIC ...
# 12  13407       ROSANA CRISTINA DUARTE RODRIGUES SERRALHERIA
# 13  13408      CELIO RODRIGUES DE MORAES DEPOSITO DE BANANAS
# 14  13721                     MAQFRAN COMERCIO DE PECAS LTDA
# 15  21181                   MOURA & SILVA MERCEARIA LIMITADA
# 16  21858                   PAMARATI COMERCIO DE RACOES LTDA
# 17  22277                     INACIO RODRIGUES DO NASCIMENTO
# 18  24205                    SUELY LEME MARI ANI 25086572800
# 19  26805                       SUELI BATISTA DA COSTA SILVA
#
#     natureza_juridica  qualificacao_responsavel capital_social  porte  \
# 0                2240                        49           0,00      1
# 1                2062                        49           0,00      5
# 2                3034                        32           0,00      5
# 3                2135                        50           0,00      5
# 4                2062                        49        4000,00      1
# 5                2062                        49           0,00      5
# 6                2062                        49           0,00      5
# 7                2062                        49           0,00      5
# 8                2135                        50           0,00      5
# 9                2135                        50           0,00      5
# 10               2062                        49           0,00      5
# 11               2062                        49           0,00      5
# 12               2135                        50           0,00      5
# 13               2135                        50           0,00      5
# 14               2062                        49           0,00      1
# 15               2062                        49           0,00      5
# 16               2135                        50           0,00      1
# 17               2135                        50           0,00      5
# 18               2135                        50        1000,00      1
# 19               2135                        50           0,00      5
#
#    ente_federativo
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# 5             None
# 6             None
# 7             None
# 8             None
# 9             None
# 10            None
# 11            None
# 12            None
# 13            None
# 14            None
# 15            None
# 16            None
# 17            None
# 18            None
# 19            None
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_22['cnpj'].plot(kind='hist', bins=20, title='cnpj')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['natureza_juridica'].plot(kind='hist', bins=20, title='natureza_juridica')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['qualificacao_responsavel'].plot(kind='hist', bins=20, title='qualificacao_responsavel')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['porte'].plot(kind='hist', bins=20, title='porte')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_26.groupby('capital_social').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_27.plot(kind='scatter', x='cnpj', y='natureza_juridica', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='natureza_juridica', y='qualificacao_responsavel', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='qualificacao_responsavel', y='porte', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['cnpj']
#   ys = series['natureza_juridica']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_30.sort_values('cnpj', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('capital_social')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='capital_social', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('cnpj')
# _ = plt.ylabel('natureza_juridica')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['cnpj']
#   ys = series['qualificacao_responsavel']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_31.sort_values('cnpj', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('capital_social')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='capital_social', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('cnpj')
# _ = plt.ylabel('qualificacao_responsavel')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['cnpj']
#   ys = series['porte']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('cnpj', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('capital_social')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='capital_social', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('cnpj')
# _ = plt.ylabel('porte')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['cnpj']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'cnpj'}, axis=1)
#               .sort_values('cnpj', ascending=True))
#   xs = counted['cnpj']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('cnpj', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('capital_social')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='capital_social', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('cnpj')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_34['cnpj'].plot(kind='line', figsize=(8, 4), title='cnpj')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_35['natureza_juridica'].plot(kind='line', figsize=(8, 4), title='natureza_juridica')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_36['qualificacao_responsavel'].plot(kind='line', figsize=(8, 4), title='qualificacao_responsavel')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['porte'].plot(kind='line', figsize=(8, 4), title='porte')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_38['capital_social'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_38, x='cnpj', y='capital_social', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_39['capital_social'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_39, x='natureza_juridica', y='capital_social', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_40['capital_social'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_40, x='qualificacao_responsavel', y='capital_social', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_41['capital_social'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_41, x='porte', y='capital_social', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
#qtd de registros
empresas.count()
# Out:
# 4585679

# %%
empresas.show(truncate=False)
# Out:
# +-----+--------------------------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# |cnpj |razao_social                                                                                |natureza_juridica|qualificacao_responsavel|capital_social|porte|ente_federativo|
# +-----+--------------------------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# |306  |FRANCAMAR REFRIGERACAO TECNICA S/C LTDA                                                     |2240             |49                      |0,00          |1    |NULL           |
# |1355 |BRASILEIRO & OLIVEIRA LTDA                                                                  |2062             |49                      |0,00          |5    |NULL           |
# |4820 |REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E TABELIONATO E REGISTRO DE CONSTRATOS MARITIMOS|3034             |32                      |0,00          |5    |NULL           |
# |5347 |ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS                                                |2135             |50                      |0,00          |5    |NULL           |
# |6846 |BADU E FILHOS TECIDOS LTDA                                                                  |2062             |49                      |4000,00       |1    |NULL           |
# |8416 |ELETRICA RUBI LTDA                                                                          |2062             |49                      |0,00          |5    |NULL           |
# |8992 |SHIROMA VEICULOS LTDA.                                                                      |2062             |49                      |0,00          |5    |NULL           |
# |9091 |CONTATOS BAR E LANCHONETE LTDA                                                              |2062             |49                      |0,00          |5    |NULL           |
# |9614 |ANTONIA APARECIDA DE SOUZA ULIANA                                                           |2135             |50                      |0,00          |5    |NULL           |
# |9896 |DORACY CORAT DA COSTA                                                                       |2135             |50                      |0,00          |5    |NULL           |
# |12112|LANCHONETE RIO VERMELHO LTDA                                                                |2062             |49                      |0,00          |5    |NULL           |
# |12605|VALMAR JACAREI COMERCIO DE PRODUTOS ALIMENTIC LTDA                                          |2062             |49                      |0,00          |5    |NULL           |
# |13407|ROSANA CRISTINA DUARTE RODRIGUES SERRALHERIA                                                |2135             |50                      |0,00          |5    |NULL           |
# |13408|CELIO RODRIGUES DE MORAES DEPOSITO DE BANANAS                                               |2135             |50                      |0,00          |5    |NULL           |
# |13721|MAQFRAN COMERCIO DE PECAS LTDA                                                              |2062             |49                      |0,00          |1    |NULL           |
# |21181|MOURA & SILVA MERCEARIA LIMITADA                                                            |2062             |49                      |0,00          |5    |NULL           |
# |21858|PAMARATI COMERCIO DE RACOES LTDA                                                            |2135             |50                      |0,00          |1    |NULL           |
# |22277|INACIO RODRIGUES DO NASCIMENTO                                                              |2135             |50                      |0,00          |5    |NULL           |
# |24205|SUELY LEME MARI ANI 25086572800                                                             |2135             |50                      |1000,00       |1    |NULL           |
# |26805|SUELI BATISTA DA COSTA SILVA                                                                |2135             |50                      |0,00          |5    |NULL           |
# +-----+--------------------------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# only showing top 20 rows

# %%
empresas.show(5,False)
# Out:
# +----+--------------------------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# |cnpj|razao_social                                                                                |natureza_juridica|qualificacao_responsavel|capital_social|porte|ente_federativo|
# +----+--------------------------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# |306 |FRANCAMAR REFRIGERACAO TECNICA S/C LTDA                                                     |2240             |49                      |0,00          |1    |NULL           |
# |1355|BRASILEIRO & OLIVEIRA LTDA                                                                  |2062             |49                      |0,00          |5    |NULL           |
# |4820|REGISTRO DE IMOVEIS, TABELIONATO 1 DE NOTAS E TABELIONATO E REGISTRO DE CONSTRATOS MARITIMOS|3034             |32                      |0,00          |5    |NULL           |
# |5347|ROSELY APARECIDA MONTEIRO CALTABIANO FREITAS                                                |2135             |50                      |0,00          |5    |NULL           |
# |6846|BADU E FILHOS TECIDOS LTDA                                                                  |2062             |49                      |4000,00       |1    |NULL           |
# +----+--------------------------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# only showing top 5 rows

# %%
#mostre alguns registros que tenhama palavra"hospital" em sua razaõ capital
#o'like' diferenci maiusculas de minusculas
#o 'ilike' não diferencia
empresas.where("razao_social ilike '%hospital%'").show(15, False)
# Out:
# +--------+-------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# |cnpj    |razao_social                                                             |natureza_juridica|qualificacao_responsavel|capital_social|porte|ente_federativo|
# +--------+-------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# |1756451 |AUTOMED DIST DE PRODUTOS AUTOMOTIVOS E HOSPITALARES LTDA                 |2062             |49                      |0,00          |1    |NULL           |
# |2616076 |SERVICO MEDICO HOSPITALAR DE TAGUATINGA LTDA                             |2062             |49                      |0,00          |1    |NULL           |
# |5082994 |LEBEC MEDICAL COMERCIO E SERVICOS DE SISTEMAS HOSPITALARES LTDA          |2062             |49                      |80000,00      |1    |NULL           |
# |5791196 |VEDOMED COMERCIO MEDICO HOSPITALAR LTDA                                  |2062             |49                      |0,00          |5    |NULL           |
# |7847837 |CIENTIFICA MEDICA HOSPITALAR LTDA                                        |2062             |49                      |4000000,00    |5    |NULL           |
# |8746690 |JMJB DIAGNOSTICOS E SERVICOS HOSPITALARES LTDA                           |2054             |10                      |927840,00     |5    |NULL           |
# |8992012 |HOSPITAL DE CLINICAS E MATERNIDADE DA ZONA OESTE LTDA                    |2240             |49                      |50000,00      |1    |NULL           |
# |10264741|SARE-ASSOCIACAO EVANGELICA DE CAPELANIA HOSPITALAR                       |3999             |16                      |0,00          |5    |NULL           |
# |11340967|ECHO SPINE PRODUTOS HOSPITALARES EIRELI                                  |2305             |65                      |100000,00     |1    |NULL           |
# |16586898|G C MEDIC COMERCIO E SERVICO DE PRODUTOS HOSPITALARES EIRELI             |2305             |65                      |500000,00     |1    |NULL           |
# |28767561|LK MEDICAL COMERCIO DE EQUIPAMENTOS HOSPITALARES -  EIRELI               |2305             |65                      |100000,00     |3    |NULL           |
# |29128075|ACR PRESTACAO DE SERVICOS HOSPITALARES LTDA                              |2062             |49                      |5000,00       |5    |NULL           |
# |30695382|ATM SERVICOS MEDICOS ASSESSORIA E EMPREENDIMENTOS HOSPITALARES LTDA - SCP|2127             |5                       |11000,00      |5    |NULL           |
# |41705105|EL HAJE DISTRIBUIDORA DE MATERIAIS MEDICO HOSPITALARES LTDA              |2062             |49                      |100000,00     |1    |NULL           |
# |273999  |GUIMARAES DISTRIBUIDORA HOSPITALAR LTDA                                  |2062             |49                      |0,00          |5    |NULL           |
# +--------+-------------------------------------------------------------------------+-----------------+------------------------+--------------+-----+---------------+
# only showing top 15 rows

# %%
#renomenado colunas :
empresas.withColumnsRenamed({
    "natureza_juridica" : "natureza",
    "qualificacao_responsavel" : "responsavel",
    "capital_social":"capital",
    "ente_federativo":"ente"
}).show()
# Out:
# +-----+--------------------+--------+-----------+-------+-----+----+
# | cnpj|        razao_social|natureza|responsavel|capital|porte|ente|
# +-----+--------------------+--------+-----------+-------+-----+----+
# |  306|FRANCAMAR REFRIGE...|    2240|         49|   0,00|    1|NULL|
# | 1355|BRASILEIRO & OLIV...|    2062|         49|   0,00|    5|NULL|
# | 4820|REGISTRO DE IMOVE...|    3034|         32|   0,00|    5|NULL|
# | 5347|ROSELY APARECIDA ...|    2135|         50|   0,00|    5|NULL|
# | 6846|BADU E FILHOS TEC...|    2062|         49|4000,00|    1|NULL|
# | 8416|  ELETRICA RUBI LTDA|    2062|         49|   0,00|    5|NULL|
# | 8992|SHIROMA VEICULOS ...|    2062|         49|   0,00|    5|NULL|
# | 9091|CONTATOS BAR E LA...|    2062|         49|   0,00|    5|NULL|
# | 9614|ANTONIA APARECIDA...|    2135|         50|   0,00|    5|NULL|
# | 9896|DORACY CORAT DA C...|    2135|         50|   0,00|    5|NULL|
# |12112|LANCHONETE RIO VE...|    2062|         49|   0,00|    5|NULL|
# |12605|VALMAR JACAREI CO...|    2062|         49|   0,00|    5|NULL|
# |13407|ROSANA CRISTINA D...|    2135|         50|   0,00|    5|NULL|
# |13408|CELIO RODRIGUES D...|    2135|         50|   0,00|    5|NULL|
# |13721|MAQFRAN COMERCIO ...|    2062|         49|   0,00|    1|NULL|
# |21181|MOURA & SILVA MER...|    2062|         49|   0,00|    5|NULL|
# |21858|PAMARATI COMERCIO...|    2135|         50|   0,00|    1|NULL|
# |22277|INACIO RODRIGUES ...|    2135|         50|   0,00|    5|NULL|
# |24205|SUELY LEME MARI A...|    2135|         50|1000,00|    1|NULL|
# |26805|SUELI BATISTA DA ...|    2135|         50|   0,00|    5|NULL|
# +-----+--------------------+--------+-----------+-------+-----+----+
# only showing top 20 rows

# %%
#efetivando alteração:
empresas = empresas.withColumnsRenamed({
    "natureza_juridica" : "natureza",
    "qualificacao_responsavel" : "responsavel",
    "capital_social":"capital",
    "ente_federativo":"ente"
})

# %%
empresas.show()
# Out:
# +-----+--------------------+--------+-----------+-------+-----+----+
# | cnpj|        razao_social|natureza|responsavel|capital|porte|ente|
# +-----+--------------------+--------+-----------+-------+-----+----+
# |  306|FRANCAMAR REFRIGE...|    2240|         49|   0,00|    1|NULL|
# | 1355|BRASILEIRO & OLIV...|    2062|         49|   0,00|    5|NULL|
# | 4820|REGISTRO DE IMOVE...|    3034|         32|   0,00|    5|NULL|
# | 5347|ROSELY APARECIDA ...|    2135|         50|   0,00|    5|NULL|
# | 6846|BADU E FILHOS TEC...|    2062|         49|4000,00|    1|NULL|
# | 8416|  ELETRICA RUBI LTDA|    2062|         49|   0,00|    5|NULL|
# | 8992|SHIROMA VEICULOS ...|    2062|         49|   0,00|    5|NULL|
# | 9091|CONTATOS BAR E LA...|    2062|         49|   0,00|    5|NULL|
# | 9614|ANTONIA APARECIDA...|    2135|         50|   0,00|    5|NULL|
# | 9896|DORACY CORAT DA C...|    2135|         50|   0,00|    5|NULL|
# |12112|LANCHONETE RIO VE...|    2062|         49|   0,00|    5|NULL|
# |12605|VALMAR JACAREI CO...|    2062|         49|   0,00|    5|NULL|
# |13407|ROSANA CRISTINA D...|    2135|         50|   0,00|    5|NULL|
# |13408|CELIO RODRIGUES D...|    2135|         50|   0,00|    5|NULL|
# |13721|MAQFRAN COMERCIO ...|    2062|         49|   0,00|    1|NULL|
# |21181|MOURA & SILVA MER...|    2062|         49|   0,00|    5|NULL|
# |21858|PAMARATI COMERCIO...|    2135|         50|   0,00|    1|NULL|
# |22277|INACIO RODRIGUES ...|    2135|         50|   0,00|    5|NULL|
# |24205|SUELY LEME MARI A...|    2135|         50|1000,00|    1|NULL|
# |26805|SUELI BATISTA DA ...|    2135|         50|   0,00|    5|NULL|
# +-----+--------------------+--------+-----------+-------+-----+----+
# only showing top 20 rows

# %%
#antes de converter a coluna capital teremos que subistituia a virgula por ponto
#caso contarrio o pyspark não consgue converter a coluna.. ela fica null

empresas.withColumn("capital",
                    f.regexp_replace("capital",",",".")).show()
# Out:
# +-----+--------------------+--------+-----------+-------+-----+----+
# | cnpj|        razao_social|natureza|responsavel|capital|porte|ente|
# +-----+--------------------+--------+-----------+-------+-----+----+
# |  306|FRANCAMAR REFRIGE...|    2240|         49|   0.00|    1|NULL|
# | 1355|BRASILEIRO & OLIV...|    2062|         49|   0.00|    5|NULL|
# | 4820|REGISTRO DE IMOVE...|    3034|         32|   0.00|    5|NULL|
# | 5347|ROSELY APARECIDA ...|    2135|         50|   0.00|    5|NULL|
# | 6846|BADU E FILHOS TEC...|    2062|         49|4000.00|    1|NULL|
# | 8416|  ELETRICA RUBI LTDA|    2062|         49|   0.00|    5|NULL|
# | 8992|SHIROMA VEICULOS ...|    2062|         49|   0.00|    5|NULL|
# | 9091|CONTATOS BAR E LA...|    2062|         49|   0.00|    5|NULL|
# | 9614|ANTONIA APARECIDA...|    2135|         50|   0.00|    5|NULL|
# | 9896|DORACY CORAT DA C...|    2135|         50|   0.00|    5|NULL|
# |12112|LANCHONETE RIO VE...|    2062|         49|   0.00|    5|NULL|
# |12605|VALMAR JACAREI CO...|    2062|         49|   0.00|    5|NULL|
# |13407|ROSANA CRISTINA D...|    2135|         50|   0.00|    5|NULL|
# |13408|CELIO RODRIGUES D...|    2135|         50|   0.00|    5|NULL|
# |13721|MAQFRAN COMERCIO ...|    2062|         49|   0.00|    1|NULL|
# |21181|MOURA & SILVA MER...|    2062|         49|   0.00|    5|NULL|
# |21858|PAMARATI COMERCIO...|    2135|         50|   0.00|    1|NULL|
# |22277|INACIO RODRIGUES ...|    2135|         50|   0.00|    5|NULL|
# |24205|SUELY LEME MARI A...|    2135|         50|1000.00|    1|NULL|
# |26805|SUELI BATISTA DA ...|    2135|         50|   0.00|    5|NULL|
# +-----+--------------------+--------+-----------+-------+-----+----+
# only showing top 20 rows

# %%
empresas = empresas.withColumn("capital",
                    f.regexp_replace("capital",",","."))
